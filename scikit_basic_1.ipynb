# %%
import sys

assert sys.version_info >= (3, 7)

# %%
from packaging import version
import sklearn

assert version.parse(sklearn.__version__) >= version.parse("1.0.1")

# %%
import matplotlib.pyplot as plt

plt.rc('font', size=12)
plt.rc('axes', labelsize=14, titlesize=14)
plt.rc('legend', fontsize=12)
plt.rc('xtick', labelsize=10)
plt.rc('ytick', labelsize=10)

# %%
import numpy as np

np.random.seed(42)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor # The Linear predics [[6.30165767]] which might not be true lets use k - nearest_neighbors
import numpy as np

#Lifetsat = pd.read_csv('https://github.com/ageron/data/blob/main/lifesat/lifesat.csv')
Lifetsat = pd.read_csv('https://raw.githubusercontent.com/ageron/data/main/lifesat/lifesat.csv')
print(Lifetsat)
plt.scatter(Lifetsat['GDP per capita (USD)'],Lifetsat['Life satisfaction'])
plt.show()

model = LinearRegression()

MOD = KNeighborsRegressor(n_neighbors = 3)
model.fit(Lifetsat[['GDP per capita (USD)']], Lifetsat[['Life satisfaction']])
MOD.fit(Lifetsat[['GDP per capita (USD)']], Lifetsat[['Life satisfaction']])

X_New = [[37_655.2]]
print(f"Linear reg predicts: {model.predict(X_New)}") # It expects 2d not 1d
print(f"neighbor reg predicts: { MOD.predict(X_New)}") # It expects 2d not 1d
# Out:
#            Country  GDP per capita (USD)  Life satisfaction
# 0           Russia          26456.387938                5.8
# 1           Greece          27287.083401                5.4
# 2           Turkey          28384.987785                5.5
# 3           Latvia          29932.493910                5.9
# 4          Hungary          31007.768407                5.6
# 5         Portugal          32181.154537                5.4
# 6           Poland          32238.157259                6.1
# 7          Estonia          35638.421351                5.7
# 8            Spain          36215.447591                6.3
# 9         Slovenia          36547.738956                5.9
# 10       Lithuania          36732.034744                5.9
# 11          Israel          38341.307570                7.2
# 12           Italy          38992.148381                6.0
# 13  United Kingdom          41627.129269                6.8
# 14          France          42025.617373                6.5
# ...
